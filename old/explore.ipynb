# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("race_results_cleaned.csv")
df.head()
# Out:
#    platz   stn              name                         verein  birthyear  \
# 0      1  6459     STÜTZEL Simon            LG Region Karlsruhe     1986.0
# 1      2     2  STÖCKL Christian          Feuerwehr Liedolsheim     1988.0
# 2      3   119     MÖHLER Samuel  Regierungspräsidium Karlsruhe     1996.0
# 3      4    13    WILKENS Hannes            LG Region Karlsruhe     2002.0
# 4      5    12      WEBER Yannik            LG Region Karlsruhe     1992.0
#
#   ak-pl. mw-pl.   zeit last_name first_name gender  is_male   age age_group  \
# 0   1. M   1. M  27:35   STÜTZEL      Simon      M        1  40.0     40-49
# 1   2. M   2. M  28:56    STÖCKL  Christian      M        1  38.0     30-39
# 2   3. M   3. M  29:00    MÖHLER     Samuel      M        1  30.0     30-39
# 3   4. M   4. M  29:22   WILKENS     Hannes      M        1  24.0     19-24
# 4   5. M   5. M  29:27     WEBER     Yannik      M        1  34.0     30-39
#
#    zeit_min  pace      speed  percentile
# ...

# %%
# df[df['first_name'] == 'Marcel']
df[df['age'] < 15].head(20)
# Out:
#       platz   stn               name                        verein  birthyear  \
# 69       70   474      SCHORB Julian           LG Region Karlsruhe     2012.0
# 108     109   412      MATZERATH Ole           LG Region Karlsruhe     2014.0
# 349     350  3138  ROSENGARDT Kilian             Gymnasium Neureut     2012.0
# 381     382  3249    MAURER Jonathan  Humboldt-Gymnasium Karlsruhe     2013.0
# 417     418  4616      SCHLEIPEN Ben           LG Region Karlsruhe     2013.0
# 448     449  3091     GERBER Philipp             Gymnasium Neureut     2012.0
# 653     654   933       HEWEL Niclas                           NaN     2012.0
# 697     698  3391          KNAM Noah                     Karlsruhe     2015.0
# 779     780  1440        RAHMEL Otto                           NaN     2015.0
# 786     787  4424       CHRIST Jonas           Krokodile Karlsruhe     2014.0
# 826     827  5911       SCHATZ Jacob                SVK Beiertheim     2012.0
# ...
